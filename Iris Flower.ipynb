# %% [raw]
# Task-1: Iris Flower Classification

# %% [markdown]
# Import Python Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Import Dataset

# %%
iris = pd.read_csv('C:/Users/karak/OneDrive/Desktop/INTERNSHIP/Data Science/Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Analysis

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print("Species involved:",iris["Species"].unique())
# Out:
# Species involved: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
sn.pairplot(iris, hue="Species", markers="x")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sn.scatterplot(x='SepalLengthCm', y='PetalLengthCm', data=iris, hue='Species')
plt.subplot(1,2,2)
sn.scatterplot(x='SepalWidthCm', y='PetalWidthCm', data=iris, hue='Species')
plt.show()

# %%
numeric_columns = df.select_dtypes(include = [np.number]) 
correlation_matrix = numeric_columns.corr()
print(correlation_matrix)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
plt.figure(figsize=(10,5))
sn.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
iris["Species"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sn.barplot(x='Species', y='SepalLengthCm', data=iris)
plt.subplot(1,2,2)
sn.boxplot(x='Species', y='SepalLengthCm', data=iris)
plt.show()

# %%
x=iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y=iris['Species']

# %%
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %% [markdown]
# Select Model

# %% [markdown]
# Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %% [markdown]
# Train Model

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.intercept_
# Out:
# array([  9.27663081,   2.30606447, -11.58269527])

# %%
lr.coef_
# Out:
# array([[-0.39438783,  0.84997043, -2.35937805, -1.01360546],
#        [ 0.41071417, -0.31817984, -0.14686886, -0.78510421],
#        [-0.01632634, -0.53179059,  2.50624691,  1.79870968]])

# %% [markdown]
# Prediction

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114            5.8           2.8            5.1           2.4
# 62             6.0           2.2            4.0           1.0
# 33             5.5           4.2            1.4           0.2
# 107            7.3           2.9            6.3           1.8
# 7              5.0           3.4            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 40             5.0           3.5            1.3           0.3
# 86             6.7           3.1            4.7           1.5
# 76             6.8           2.8            4.8           1.4
# 71             6.1           2.8            4.0           1.3
# 134            6.1           2.6            5.6           1.4
# 51             6.4           3.2            4.5           1.5
# 73             6.1           2.8            4.7           1.2
# 54             6.5           2.8            4.6           1.5
# ...

# %% [markdown]
# Accuracy

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
confusion_matrix(y_test, y_pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# Using KNN Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier()

# %%
model2.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred2 = model2.predict(x_test)
y_pred2
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred2)
# Out:
# 0.9666666666666667

# %% [markdown]
# Using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model3 = DecisionTreeClassifier()

# %%
model3.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3 = model3.predict(x_test)
y_pred3
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred3)
# Out:
# 1.0

# %%
result = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN', 'Decision Tree'],
    'Score': [1.0, 0.967, 1.0]})
result_iris = result.sort_values(by = 'Score', ascending = False)
result_iris = result_iris.set_index('Score')
result_iris.head()
# Out:
#                      Model
# Score
# 1.000  Logistic Regression
# 1.000        Decision Tree
# 0.967                  KNN
